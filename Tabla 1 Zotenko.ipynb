# %%
import networkx as nx
import matplotlib.pylab as plt
import numpy as np

def ldata(archive):
        f=open(archive)
        data=[]
        for line in f:
            line=line.strip()
            col=line.split("\t")
            data.append(col)
        return data

    
LIT=ldata("yeast_LIT.txt")
APMS=ldata("yeast_AP-MS.txt")
Y2H=ldata("yeast_Y2H.txt")
LITR=ldata("yeast_LIT_Reguly.txt")
PaHe=ldata("Essential_ORFs_paperHe.txt")

# for i in range (10):
#     print(LITR[i][2])

Lel=dict()

for i in range(1,len(LITR)):
    Lel[LITR[i][0]]=LITR[i][2]
print(Lel.values())
# Out:
# dict_values(['PTP2', 'STE12', 'RNA15', 'RHO1', 'SLA2', 'TCP1', 'RRP46', 'TIF4632', 'DMA1', 'SBA1', 'VPS35', 'RAD7', 'PPH21', 'NOG1', 'ERG7', 'TPD3', 'COQ3', 'TIM22', 'YBL046W', 'YPL183C', 'LSB1', 'SNU56', 'UFD2', 'NVJ1', 'AVO1', 'VAC14', 'RRD2', 'CYC8', 'ILV6', 'PHB1', 'SIN4', 'NUT1', 'PRE4', 'IWS1', 'PCF11', 'SST2', 'CDC16', 'VAC8', 'PUF6', 'NAT4', 'MAK31', 'ARB1', 'MCM6', 'PTR3', 'CWC2', 'PEX18', 'NTG2', 'APC11', 'QRI8', 'YPT6', 'SMC3', 'TFB3', 'ELP3', 'SAP185', 'TAF12', 'SIR2', 'RPL40B', 'ATM1', 'BUD21', 'GOS1', 'KOG1', 'RGT1', 'OST5', 'FAA4', 'SML1', 'CAD1', 'MLH3', 'LOS1', 'TRM3', 'YBR025C', 'MAD2', 'RPO41', 'TPM2', 'RAD14', 'VHS3', 'TSR2', 'IRE1', 'MIF2', 'TAF3', 'HOT1', 'SKG6', 'RUD3', 'ARP7', 'POP2', 'UTP21', 'BRR2', 'ELC1', 'POX1', 'HGH1', 'RCK2', 'SMP1', 'STE7', 'GAL80', 'KTI11', 'PSF2', 'UBA1', 'INP52', 'HSP150', 'EXO70', 'STE11', 'TEM1', 'EPS1', 'SNO1', 'GDI1', 'BBC1', 'CDC3', 'SPT20', 'CDC40', 'DSN1', 'UTP4', 'BUD5', 'MTW1', 'SSA3', 'PAT1', 'RRB1', 'HSP82', 'SNP1', 'CSH1', 'DPB4', 'PMT2', 'YDL099W', 'DAD2', 'PIH1', 'VPS5', 'UBX7', 'DSE1', 'MTF1', 'SNC2', 'STM1', 'SEH1', 'UBC12', 'OST2', 'RPN9', 'RAD55', 'POL32', 'SIT1', 'BET5', 'SPO21', 'CAF20', 'ZIP1', 'DBF20', 'SNZ1', 'CIT1', 'SDC1', 'TRK1', 'RPT6', 'YJL122W', 'HMRA1', 'PRP9', 'SHE2', 'MRE11', 'BFA1', 'GLC7', 'DBP5', 'RPA49', 'APC4', 'HBS1', 'HO', 'WHI2', 'TPS1', 'KRR1', 'KAP95', 'SWI5', 'RPN1', 'CFT1', 'RTF1', 'SQT1', 'SEM1', 'RPC17', 'ELF1', 'DAL80', 'RIX1', 'SSF1', 'YKT6', 'DCP2', 'BRE5', 'NDL1', 'CRN1', 'SLK19', 'SRB2', 'HIR2', 'SWH1', 'SLU7', 'GCR1', 'SMY1', 'TCM62', 'SUB2', 'DLD2', 'NUP120', 'SRM1', 'ELP2', 'VMA10', 'MYO4', 'MED8', 'ATS1', 'FAT1', 'RNR1', 'GYP6', 'DAD1', 'PWP1', 'SPH1', 'NUF2', 'OST3', 'DIG2', 'SSL2', 'PMT1', 'CAF4', 'MSO1', 'LSG1', 'FAR7', 'POL30', 'END3', 'SUA7', 'MKK2', 'MAK21', 'SET3', 'RRP5', 'DPB2', 'SME1', 'ITT1', 'SSU72', 'PAM18', 'MRC1', 'RRM3', 'MRS11', 'AXL1', 'OPI1', 'SNF4', 'BEM2', 'INO80', 'SYF1', 'GCD7', 'PUP3', 'KEL3', 'DIS3', 'RPB8', 'MPS1', 'MLP1', 'RRN3', 'PUT3', 'GGA1', 'ESC2', 'PDS1', 'DBF2', 'RAD53', 'CDC39', 'TOP3', 'CAP1', 'CSI1', 'NHP2', 'CAF40', 'DCN1', 'TSC11', 'TFS1', 'REC102', 'KEL1', 'AXL2', 'ESF1', 'PPH3', 'GCD6', 'GIN4', 'SWM1', 'BET3', 'DCP1', 'RDH54', 'HAT1', 'SSS1', 'NTC20', 'RGD1', 'CTK1', 'PUP1', 'SSO1', 'PRE10', 'ERG27', 'PET54', 'CLC1', 'MCM22', 'SCP160', 'TRS31', 'HRP1', 'IMH1', 'CDC37', 'FIR1', 'CUE1', 'VPS71', 'GSP2', 'RAD16', 'HSF1', 'SGT1', 'CNA1', 'MYO3', 'MPT5', 'SHU2', 'TAH11', 'TRS20', 'APC2', 'RVB1', 'KAE1', 'MDL1', 'SSL1', 'HHF1', 'NOP7', 'RPS7A', 'NBP2', 'PMT3', 'IPL1', 'MF(ALPHA)1', 'PFY1', 'TLG1', 'ZDS1', 'MSB2', 'NEM1', 'BUL1', 'GPA2', 'RIM15', 'DBP7', 'CHD1', 'RAD4', 'SHG1', 'CHL1', 'YPT1', 'ATP18', 'ENT3', 'JSN1', 'SHU1', 'MSL5', 'YFR022W', 'RSC6', 'CDC20', 'UBC4', 'ATG4', 'LST8', 'PHO85', 'CLP1', 'CDC31', 'PTA1', 'PRE3', 'SEN2', 'TIF4631', 'TIM50', 'RPB3', 'TRA1', 'TRZ1', 'MSI1', 'UBA4', 'HRB1', 'PSF1', 'MUS81', 'LIF1', 'RPO26', 'SPT7', 'UTP14', 'YPR004C', 'VPS34', 'TSL1', 'HOS3', 'HMLALPHA1', 'DYS1', 'RLR1', 'CUP5', 'RAS2', 'SEC9', 'ACT1', 'CDC28', 'YNL260C', 'GTS1', 'SPP2', 'SUI2', 'NMD5', 'ADR1', 'RDS3', 'MEC3', 'NAN1', 'SSD1', 'SLD5', 'STB1', 'NAM8', 'TIF2', 'VPS24', 'SDA1', 'POT1', 'RPT4', 'DOT1', 'LSB6', 'HAP5', 'YGR046W', 'ECM11', 'TAO3', 'SOF1', 'SGF73', 'MSN2', 'SNU66', 'SMC4', 'CDC48', 'UTP18', 'MIP1', 'UBC5', 'FES1', 'PPH22', 'RTN1', 'ALF1', 'FKS1', 'QRI2', 'VPS33', 'SEC20', 'CLB2', 'BNI5', 'SIL1', 'CDC12', 'MNN10', 'RPN13', 'CDC13', 'RER1', 'ERG1', 'DAD4', 'APL1', 'SRP101', 'YKE2', 'VTI1', 'SNF2', 'NNF1', 'RAD26', 'MOG1', 'YRR1', 'STE14', 'PKC1', 'SPC97', 'PSK2', 'ATG20', 'ATG11', 'GLO3', 'CDC54', 'ARP8', 'PCL7', 'ADY3', 'ERB1', 'HEX3', 'GEA1', 'SSN8', 'YPT11', 'TLG2', 'SEC4', 'NIP1', 'TAF1', 'CDC46', 'SPC25', 'PRP8', 'RPS9B', 'LSB5', 'RPO31', 'RIX7', 'ACE2', 'LIN1', 'BUD3', 'EST1', 'CLA4', 'TIF5', 'RRP45', 'RHO3', 'HSV2', 'YCG1', 'USO1', 'RAD3', 'RSC1', 'SES1', 'MED7', 'SDS22', 'PEX25', 'SWI3', 'TAF10', 'NMD2', 'CTI6', 'APL4', 'ROG1', 'KEX2', 'SPT16', 'SUP45', 'KIN2', 'M ...
